# %%
import requests

api_key = "162281490b68ef33f84de64aa9d6945b"

url = "http://api.eia.gov/series/?api_key="+api_key+"&series_id=PET.EMM_EPM0_PTE_SNY_DPG.W"

response = requests.get(url).json()

response
# Out:
# {'request': {'command': 'series', 'series_id': 'PET.EMM_EPM0_PTE_SNY_DPG.W'},
#  'series': [{'series_id': 'PET.EMM_EPM0_PTE_SNY_DPG.W',
#    'name': 'New York All Grades All Formulations Retail Gasoline Prices, Weekly',
#    'units': 'Dollars per Gallon',
#    'f': 'W',
#    'unitsshort': '$/gal',
#    'description': 'New York All Grades All Formulations Retail Gasoline Prices',
#    'copyright': 'None',
#    'source': 'EIA, U.S. Energy Information Administration',
#    'iso3166': 'USA-NY',
#    'geography': 'USA-NY',
#    'start': '20000605',
#    'end': '20200601',
#    'updated': '2020-06-01T19:45:16-0400',
#    'data': [['20200601', 2.189],
#     ['20200525', 2.189],
#     ['20200518', 2.17],
#     ['20200511', 2.16],
#     ['20200504', 2.124],
#     ['20200427', 2.136],
#     ['20200420', 2.189],
#     ['20200413', 2.229],
#     ['20200406', 2.267],
#     ['20200330', 2.31],
#     ['20200323', 2.376],
#     ['20200316', 2.455],
#     ['20200309', 2.547],
# ...

# %%
response["series"][0]["data"]
# Out:
# [['20200601', 1.943],
#  ['20200525', 1.941],
#  ['20200518', 1.819],
#  ['20200511', 1.817],
#  ['20200504', 1.821],
#  ['20200427', 1.837],
#  ['20200420', 1.86],
#  ['20200413', 1.897],
#  ['20200406', 1.949],
#  ['20200330', 2.014],
#  ['20200323', 2.121],
#  ['20200316', 2.217],
#  ['20200309', 2.309],
#  ['20200302', 2.374],
#  ['20200224', 2.444],
#  ['20200217', 2.357],
#  ['20200210', 2.409],
#  ['20200203', 2.401],
#  ['20200127', 2.474],
#  ['20200120', 2.546],
#  ['20200113', 2.52],
#  ['20200106', 2.576],
#  ['20191230', 2.494],
#  ['20191223', 2.457],
#  ['20191216', 2.494],
#  ['20191209', 2.554],
#  ['20191202', 2.48],
#  ['20191125', 2.402],
#  ['20191118', 2.399],
#  ['20191111', 2.429],
#  ['20191104', 2.473],
#  ['20191028', 2.418],
#  ['20191021', 2.488],
#  ['20191014', 2.437],
#  ['20191007', 2.495],
#  ['20190930', 2.465],
#  ['20190923', 2.528],
#  ['20190916', 2.429],
#  ['20190909', 2.459],
#  ['20190902', 2.48],
#  ['20190826', 2.389],
# ...
